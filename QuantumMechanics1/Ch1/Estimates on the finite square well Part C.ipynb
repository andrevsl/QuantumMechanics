# %%
# %%latex
# $
#
# \\ from \ Part \ B \ we \ have\\
#
# \kappa=\frac{\sqrt{-2mE}}{ \hbar}  \ and \
# k=\frac{\sqrt{2m(V_0+E)}}{ \hbar}
# \\
# (\kappa a)^2=\frac{-2ma^2}{ \hbar^2}  \ and \
# (ka)^2=\frac{2ma^2(V_0+E)}{ \hbar^2}
#
#
# \\ from \ Part \ C \ we \ infer \
#
# z_0^2=\frac{2ma^2V_0}{ \hbar^2}
#
#
# \\ Thus, \\
#
# (\kappa a)^2+(ka)^2=z_0^2
# \\
#
#
# \kappa a= ka\ tan(ka)=  z\ tan(z)     \\
#
#
# tan \ z=\sqrt{\frac{ z_0^2}{z^2}-1}  \\
#
# Considering \ a shallow \ and \ narrow \ width,
# z_0 \ is \ very \ small\\
#
# In \ order \ to \ \sqrt{\frac{ z_0^2}{z^2}-1} \ be \ real ,\
# z<z_0,\   being \ z \ also \ small,\ then \\
#
# \\
# tan (z) \approx z=\sqrt{\frac{ z_0^2}{z^2}-1}  \\
#
# z^2={\frac{ z_0^2}{z^2}-1}            \\
# z^4+z^2-z_0^2=0 \\
#
# with \ u=z^2\\
#
# u^2+u-z_0^2=0 \\
#
# taking \ the \ positive\ root \\
#
# u=\frac{-1+\sqrt{1-4(-z_0^2)}}{2}=z^2=\frac{-1+\sqrt{1+4(+z_0^2)}}{2} \\
#
#
# As \ E \ can \ be \ writen \ as \\
#
# z^2-z_0^2=\frac{2ma^2E}{\hbar^2}=\frac{z_0^2E}{V_0}\\
#
#
# E=V_0(\frac{z^2}{z_0^2}-1) \\
#
# then \\
#
# E=V_0(\frac{-1+\sqrt{1+4(+z_0^2)}}{2z_0^2}-1) \\
#
# \\ being \ z_0 \\ very \ small\ it \ reduces \ to \\
#
# E \approx-V_0\ z_0^2 \\
#
# $
# Out:
# $
#
# \\ from \ Part \ B \ we \ have\\
#
# \kappa=\frac{\sqrt{-2mE}}{ \hbar}  \ and \
# k=\frac{\sqrt{2m(V_0+E)}}{ \hbar}
# \\
# (\kappa a)^2=\frac{-2ma^2}{ \hbar^2}  \ and \
# (ka)^2=\frac{2ma^2(V_0+E)}{ \hbar^2}
#
#
# \\ from \ Part \ C \ we \ infer \
#
# z_0^2=\frac{2ma^2V_0}{ \hbar^2}
#
#
# \\ Thus, \\
#
# (\kappa a)^2+(ka)^2=z_0^2
# \\
#
#
# \kappa a= ka\ tan(ka)=  z\ tan(z)     \\
#
#
# tan \ z=\sqrt{\frac{ z_0^2}{z^2}-1}  \\
#
# Considering \ a shallow \ and \ narrow \ width,
# z_0 \ is \ very \ small\\
#
# In \ order \ to \ \sqrt{\frac{ z_0^2}{z^2}-1} \ be \ real ,\
# z<z_0,\   being \ z \ also \ small,\ then \\
#
# \\
# tan (z) \approx z=\sqrt{\frac{ z_0^2}{z^2}-1}  \\
#
# z^2={\frac{ z_0^2}{z^2}-1}            \\
# z^4+z^2-z_0^2=0 \\
#
# with \ u=z^2\\
#
# u^2+u-z_0^2=0 \\
#
# taking \ the \ positive\ root \\
#
# u=\frac{-1+\sqrt{1-4(-z_0^2)}}{2}=z^2=\frac{-1+\sqrt{1+4(+z_0^2)}}{2} \\
#
#
# As \ E \ can \ be \ writen \ as \\
#
# ...

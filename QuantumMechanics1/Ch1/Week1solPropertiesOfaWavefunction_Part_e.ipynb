# %% [markdown]
# ## Part e

# %%
# %%latex
# $
# E\Psi(x)=\overline{\rm H}\Psi(x)   \\
#
# E\Psi(x)=[-\frac{ \hbar^2}{2m} \frac{\partial^2 }{\partial x^2} +V(x)]\Psi(x)   \\
#
# reordering \ and \ isolating \ V(x) \\
#
# V(x)=E+\frac{1}{\Psi(x)}\frac{ \hbar^2}{2m} \frac{\partial^2 \Psi(x)}{\partial x^2}   \\
#
#  since \ \Psi(x)=Nxe^{(-  \frac{\alpha}{2}  x^2)} \\
#
#   \frac{\partial \Psi(x)}{\partial x} =
#   N(e^{(-  \frac{\alpha}{2}  x^2) )} -\alpha x^2e^{(-  \frac{\alpha}{2}  x^2) }) \\
#
#
#    \frac{\partial^2 \Psi(x)}{\partial x^2} =
#
#      N(-\alpha x e^{(-  \frac{\alpha}{2}  x^2) )}
#      -2\alpha x e^{(-  \frac{\alpha}{2}  x^2) )}
#
#      -\alpha^2 x^3e^{(-  \frac{\alpha}{2}  x^2) }) \\
#
#
#    \frac{\partial^2 \Psi(x)}{\partial x^2} =
#
#      N(-3\alpha x e^{(-  \frac{\alpha}{2}  x^2) )}
#
#      -\alpha^2 x^3e^{(-  \frac{\alpha}{2}  x^2) }) \\
#
#
#
#      \frac{1}{\Psi(x)} \frac{\partial^2 \Psi(x)}{\partial x^2}=
#
#      -3\alpha+\alpha^2 x^2
#
#      \\
#
#      then , \\
#
#      V(x)=E+\frac{ \hbar^2}{2m}  (-3\alpha+\alpha^2 x^2)\\
#
#
#      V(0)=E+\frac{ \hbar^2}{2m}(-3\alpha)=0\\
#
#
#      E=\frac{ 3\alpha\hbar^2}{2m} \
#
#
#      and,\
#
#      V(x)=\frac{ \alpha^2 x^2\hbar^2}{2m}
#
#
#
#
#
# $
# Out:
# $
# E\Psi(x)=\overline{\rm H}\Psi(x)   \\
#
# E\Psi(x)=[-\frac{ \hbar^2}{2m} \frac{\partial^2 }{\partial x^2} +V(x)]\Psi(x)   \\
#
# reordering \ and \ isolating \ V(x) \\
#
# V(x)=E+\frac{1}{\Psi(x)}\frac{ \hbar^2}{2m} \frac{\partial^2 \Psi(x)}{\partial x^2}   \\
#
#  since \ \Psi(x)=Nxe^{(-  \frac{\alpha}{2}  x^2)} \\
#
#   \frac{\partial \Psi(x)}{\partial x} =
#   N(e^{(-  \frac{\alpha}{2}  x^2) )} -\alpha x^2e^{(-  \frac{\alpha}{2}  x^2) }) \\
#
#
#    \frac{\partial^2 \Psi(x)}{\partial x^2} =
#
#      N(-\alpha x e^{(-  \frac{\alpha}{2}  x^2) )}
#      -2\alpha x e^{(-  \frac{\alpha}{2}  x^2) )}
#
#      -\alpha^2 x^3e^{(-  \frac{\alpha}{2}  x^2) }) \\
#
#
#    \frac{\partial^2 \Psi(x)}{\partial x^2} =
#
#      N(-3\alpha x e^{(-  \frac{\alpha}{2}  x^2) )}
#
#      -\alpha^2 x^3e^{(-  \frac{\alpha}{2}  x^2) }) \\
#
#
#
#      \frac{1}{\Psi(x)} \frac{\partial^2 \Psi(x)}{\partial x^2}=
#
#      -3\alpha+\alpha^2 x^2
#
#      \\
#
#      then , \\
#
# ...

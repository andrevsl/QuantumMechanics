# %%
# %%latex
# $
# E\Psi(x)=\overline{\rm H}\Psi(x)   \\
#
# for \ bound \ states\ ,
#
# E\Psi(x)=[-\frac{ \hbar^2}{2m} \frac{\partial^2 }{\partial x^2} -V_0]\Psi(x)   \\
#
# -\frac{ 2mE}{\hbar^2}\Psi(x)=\frac{\partial^2 \Psi(x)}{\partial x^2}      \\
#
#
# for \ 0<x<3L \  due \ to \ infinity \ barrier \ potential\\ the \ wavefunction \ vanishes\ inside \ side \ walls \\
# thus, \ \Psi(0)=0 \ and \ \Psi(3L)=0
#
# -k^2\Psi(x)=\frac{\partial^2 \Psi(x)}{\partial x^2}    \\ (complex \ exponentials,\ sin, \ cos ) \\
#
#
# k^2=\frac{2mE}{\hbar^2}  \\
#
#
# \Psi(x)=N*sin(kx)   \\
#
# \Psi(0)=0 \ is \ straightfoward \ conveyed \ by \ sin \ function \\
#
#
#
# \Psi(3L)=N*sin(k\ 3L)=0   \Longrightarrow  k 3L=n \pi \\
#
# k=\frac{n \pi}{3L} \\
#
# Ensuring \ the \ normalization \\
#
# \intop_{ -\infty }^{\infty }  \Psi(x)^*\Psi(x)      dx=1 \\
#
#
#  N^2\intop_{ -\infty }^{\infty }sin^2(\frac{n \pi x}{3L})     dx=1 \\
#
#
#
#  N^2\intop_{ 0 }^{3L }(1 -cos^2(\frac{n \pi x}{3L}))     dx=1 \\
#
#  -N^2\intop_{ 0 }^{3L }(cos^2(\frac{n \pi x}{3L})-1)     dx=1 \\
#
#   -N^2\intop_{ 0 }^{3L }(2cos^2(\frac{n \pi x}{3L})-1-1)     dx=2 \\
#
#     -N^2\intop_{ 0 }^{3L }(cos(\frac{2n \pi x}{3L})-1)     dx=2 \\
#
#         -N^2\intop_{ 0 }^{3L }(cos(\frac{2n \pi x}{3L}) dx
#
#
#         +N^2 3L=2\intop_{ 0 }^{3L }     dx=2 \\
#
#
#  N^2 3L=2  \\
#  N=\sqrt{\frac{2}{3L}} \\
#
#
#  \frac{2mE}{\hbar^2} =\frac {n^2 \pi^2}{9L^2}  \\
#
#  E= \frac {n^2 \pi^2\hbar^2}{18mL^2}
#
#
# $
# Out:
# $
# E\Psi(x)=\overline{\rm H}\Psi(x)   \\
#
# for \ bound \ states\ ,
#
# E\Psi(x)=[-\frac{ \hbar^2}{2m} \frac{\partial^2 }{\partial x^2} -V_0]\Psi(x)   \\
#
# -\frac{ 2mE}{\hbar^2}\Psi(x)=\frac{\partial^2 \Psi(x)}{\partial x^2}      \\
#
#
# for \ 0<x<3L \  due \ to \ infinity \ barrier \ potential\\ the \ wavefunction \ vanishes\ inside \ side \ walls \\
# thus, \ \Psi(0)=0 \ and \ \Psi(3L)=0
#
# -k^2\Psi(x)=\frac{\partial^2 \Psi(x)}{\partial x^2}    \\ (complex \ exponentials,\ sin, \ cos ) \\
#
#
# k^2=\frac{2mE}{\hbar^2}  \\
#
#
# \Psi(x)=N*sin(kx)   \\
#
# \Psi(0)=0 \ is \ straightfoward \ conveyed \ by \ sin \ function \\
#
#
#
# \Psi(3L)=N*sin(k\ 3L)=0   \Longrightarrow  k 3L=n \pi \\
#
# k=\frac{n \pi}{3L} \\
#
# Ensuring \ the \ normalization \\
#
# \intop_{ -\infty }^{\infty }  \Psi(x)^*\Psi(x)      dx=1 \\
#
#
#  N^2\intop_{ -\infty }^{\infty }sin^2(\frac{n \pi x}{3L})     dx=1 \\
#
#
#
#  N^2\intop_{ 0 }^{3L }(1 -cos^2(\frac{n \pi x}{3L}))     dx=1 \\
#
# ...

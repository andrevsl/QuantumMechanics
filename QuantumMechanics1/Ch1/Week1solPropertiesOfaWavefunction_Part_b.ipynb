# %% [markdown]
# ### Part b1

# %%
# %%latex
# $
#
# <\overline{\rm p}>= \intop_{ -\infty }^{\infty }  { \Psi^*(x) \overline{\rm p}\Psi(x)}dx\\
#
#
#
# <\overline{\rm p}>=2\sqrt{\frac{ \alpha ^3   }{ \pi  }}\intop_{ -\infty }^{\infty }  xe^{(-  \frac{\alpha}{2}  x^2)}
# \frac{ \hbar }{i} \frac{\partial }{\partial x} (xe^{(-  \frac{\alpha}{2}  x^2)  })     dx  \\
#
# =2\sqrt{\frac{ \alpha ^3   }{ \pi  }}\frac{ \hbar }{i}I \\
#
# I=\intop_{ -\infty }^{\infty }  xe^{(-  \alpha  x^2)}
# \frac{\partial }{\partial x} (xe^{(-  \alpha  x^2)  })     dx  \\
#
# since \ \int u^{'}v dx=uv -   \int v^{'}udx                   \\
#
#
#  imposing \ u=xe^{(-  \frac{\alpha}{2}  x^2)  } \ and \ v=xe^{(-  \frac{\alpha}{2}  x^2)  } \\
#
#
#
#
#  <\overline{\rm p}>=0
#  I=x^2e^{(-  \alpha  x^2)}{|_{-\infty} ^{+\infty}}
#  - I \\
#  2I=x^2e^{(-  \alpha  x^2)}{|_{-\infty} ^{+\infty}} =0   \\
#
#
# $
# Out:
# $
#
# <\overline{\rm p}>= \intop_{ -\infty }^{\infty }  { \Psi^*(x) \overline{\rm p}\Psi(x)}dx\\
#
#
#
# <\overline{\rm p}>=2\sqrt{\frac{ \alpha ^3   }{ \pi  }}\intop_{ -\infty }^{\infty }  xe^{(-  \frac{\alpha}{2}  x^2)}
# \frac{ \hbar }{i} \frac{\partial }{\partial x} (xe^{(-  \frac{\alpha}{2}  x^2)  })     dx  \\
#
# =2\sqrt{\frac{ \alpha ^3   }{ \pi  }}\frac{ \hbar }{i}I \\
#
# I=\intop_{ -\infty }^{\infty }  xe^{(-  \alpha  x^2)}
# \frac{\partial }{\partial x} (xe^{(-  \alpha  x^2)  })     dx  \\
#
# since \ \int u^{'}v dx=uv -   \int v^{'}udx                   \\
#
#
#  imposing \ u=xe^{(-  \frac{\alpha}{2}  x^2)  } \ and \ v=xe^{(-  \frac{\alpha}{2}  x^2)  } \\
#
#
#
#
#  <\overline{\rm p}>=0
#  I=x^2e^{(-  \alpha  x^2)}{|_{-\infty} ^{+\infty}}
#  - I \\
#  2I=x^2e^{(-  \alpha  x^2)}{|_{-\infty} ^{+\infty}} =0   \\
#
#
# $

# %% [markdown]
# ### Part b2

# %%
# %%latex
# $
# <\overline{\rm p^2}>= \intop_{ -\infty }^{\infty }  { \Psi^*(x) \overline{\rm p^2}\Psi(x)}dx\\
#
#
#
# <\overline{\rm p}>=2\sqrt{\frac{ \alpha ^3   }{ \pi  }}\intop_{ -\infty }^{\infty }  xe^{(-  \frac{\alpha}{2}  x^2)}
#  (-\hbar^2)  \frac{\partial ^2}{\partial x ^2} (xe^{(-  \frac{\alpha}{2}  x^2)  })     dx  \\
#
# =-2\sqrt{\frac{ \alpha ^3   }{ \pi  }} \hbar^2 I \\
#
# I=\intop_{ -\infty }^{\infty }  xe^{(-  \frac{\alpha}{2}  x^2)}
# \frac{\partial ^2}{\partial x ^2} (xe^{(-  \frac{\alpha}{2}  x^2)  })     dx  \\
#
#
# I=\intop_{ -\infty }^{\infty } u
# \frac{\partial ^2}{\partial x ^2} (u )     dx  \\
#
# imposing \ u=xe^{(-  \frac{\alpha}{2}  x^2) }  \\
#
#
# I=\intop_{ -\infty }^{\infty }\ dx[\frac{\partial }{\partial x }  (u
# \frac{\partial }{\partial x } (u ))-\frac{\partial u}{\partial x }\frac{\partial u}{\partial x } ) ]    \\
#
#
# I= u\frac{\partial u}{\partial x }{|_{-\infty} ^{+\infty}} +
# \intop_{ -\infty }^{\infty }\ \frac{\partial u}{\partial x }\frac{\partial u}{\partial x } dx ]    \\\\
#
# I=
# \intop_{ -\infty }^{\infty }\ \frac{\partial u}{\partial x }\frac{\partial u}{\partial x } dx    \\\\
#
# \frac{\partial u}{\partial x }=   e^{(-  \frac{\alpha}{2}  x^2) }-  \alpha x^2e^{(-  \frac{\alpha}{2}  x^2) }\\
#
#  (\frac{\partial u}{\partial x })^2 = (
#  e^{(-  \frac{\alpha}{2}  x^2) }
#  -  \alpha x^2e^{(-  \frac{\alpha}{2}  x^2) })^2\\
#
#
#   (\frac{\partial u}{\partial x })^2 =
#       (  e^{(-  \alpha  x^2) }
#     -2 \alpha x^2 e^{(-  \alpha x^2) }
#      +  \alpha^2 x^4e^{(-  \alpha x^2) })\\
#
#
# I=
# \intop_{ -\infty }^{\infty }     e^{(- \alpha  x^2) }
#     -2 \alpha \intop_{ -\infty }^{\infty }   x^2 e^{(-  \alpha x^2) }
#      +  \alpha^2 \intop_{ -\infty }^{\infty } x^4e^{(-  \alpha x^2) }      \\
#
# integrating \ by \ parts \ the \ first \ term    \\
# I=
# xe^{(- \alpha  x^2)}{|_{-\infty} ^{+\infty}}
#     + 2\alpha\intop_{ -\infty }^{\infty }     x^2e^{(- \alpha  x^2) }dx
#     -2 \alpha \intop_{ -\infty }^{\infty }   x^2 e^{(-  \alpha x^2) }
#      +  \alpha^2 \intop_{ -\infty }^{\infty } x^4e^{(-  \alpha x^2) }      \\
#
#
# I=
# xe^{(- \alpha  x^2)}{|_{-\infty} ^{+\infty}}
# +\frac{3}{2\alpha}  \frac{\sqrt{ \pi } }{2  \alpha^{3/2} } \\
#
#  <\overline{\rm p^2}>=-2\sqrt{\frac{ \alpha ^3   }{ \pi  }} \hbar^2 \frac{3}{2\alpha}  \frac{\sqrt{ \pi } }{2  \alpha^{3/2} }
#   \\
#
#    <\overline{\rm p^2}>= \hbar^2 \frac{3}{2\alpha}
#   \\
# $
# Out:
# $
# <\overline{\rm p^2}>= \intop_{ -\infty }^{\infty }  { \Psi^*(x) \overline{\rm p^2}\Psi(x)}dx\\
#
#
#
# <\overline{\rm p}>=2\sqrt{\frac{ \alpha ^3   }{ \pi  }}\intop_{ -\infty }^{\infty }  xe^{(-  \frac{\alpha}{2}  x^2)}
#  (-\hbar^2)  \frac{\partial ^2}{\partial x ^2} (xe^{(-  \frac{\alpha}{2}  x^2)  })     dx  \\
#
# =-2\sqrt{\frac{ \alpha ^3   }{ \pi  }} \hbar^2 I \\
#
# I=\intop_{ -\infty }^{\infty }  xe^{(-  \frac{\alpha}{2}  x^2)}
# \frac{\partial ^2}{\partial x ^2} (xe^{(-  \frac{\alpha}{2}  x^2)  })     dx  \\
#
#
# I=\intop_{ -\infty }^{\infty } u
# \frac{\partial ^2}{\partial x ^2} (u )     dx  \\
#
# imposing \ u=xe^{(-  \frac{\alpha}{2}  x^2) }  \\
#
#
# I=\intop_{ -\infty }^{\infty }\ dx[\frac{\partial }{\partial x }  (u
# \frac{\partial }{\partial x } (u ))-\frac{\partial u}{\partial x }\frac{\partial u}{\partial x } ) ]    \\
#
#
# I= u\frac{\partial u}{\partial x }{|_{-\infty} ^{+\infty}} +
# ...
